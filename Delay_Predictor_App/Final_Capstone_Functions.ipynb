# %%
# Install Java, Spark, Findspark and PySpark
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://apache.osuosl.org/spark/spark-2.4.4/spark-2.4.4-bin-hadoop2.7.tgz
# !tar xf spark-2.4.4-bin-hadoop2.7.tgz

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.4-bin-hadoop2.7"

# !pip install -q findspark
# !pip install pyspark

# mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Collecting pyspark
#   Downloading https://files.pythonhosted.org/packages/87/21/f05c186f4ddb01d15d0ddc36ef4b7e3cedbeb6412274a41f26b55a650ee5/pyspark-2.4.4.tar.gz (215.7MB)
#      |████████████████████████████████| 215.7MB 61kB/s
# Collecting py4j==0.10.7
#   Downloading https://files.pythonhosted.org/packages/e3/53/c737818eb9a7dc32a7cd4f1396e787bd94200c3997c72c1dbe028587bd76/py4j-0.10.7-py2.py3-none-any.whl (197kB)
#      |████████████████████████████████| 204kB 8.6MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-2.4.4-py2.py3-none-any.whl size=216130387 sha256=bce311c5b7e39764e56f15dc838b0566f25b7e1e4151b6c20b3a3ec2cd78d81b
#   Stored in directory: /root/.cache/pip/wheels/ab/09/4d/0d184230058e654eb1b04467dbc1292f00eaa186544604b471
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.7 pyspark-2.4.4
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# # Install packages

# %%
import requests
import pprint
import pandas as pd
import json
from pandas.io.json import json_normalize
import shutil

# %%
# let's make a GET request

def build_url(params):
    url = (
        f"{api_params['url']}/{api_params['airport']}/dep/{api_params['year']}"
        f"/{api_params['month']}/{api_params['day']}/{api_params['hour']}"
    )
    
    return url

api_params = {
    'url'    : 'https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status',
    'airport': 'lax',
    'year'   : '2019',
    'month'  : '10',
    'day'    : '20',
    'hour'   : '6'
}

creds = {
    'appId' : 'c1272abb',
    'appKey': '58dfa6e47bc7ec284869e36f94613a6f'
}

res = requests.get(build_url(api_params), params=creds)
print(res.status_code)
print(res.json())
# Out:
# 200
# {'request': {'hourOfDay': {'requested': '6', 'interpreted': 6}, 'utc': {'interpreted': False}, 'numHours': {'interpreted': 1}, 'url': 'https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/dep/2019/10/20/6', 'nonstopOnly': {'interpreted': False}, 'airport': {'fsCode': 'LAX', 'requestedCode': 'lax'}, 'date': {'year': '2019', 'month': '10', 'day': '20'}}, 'error': {'httpStatusCode': 400, 'errorId': '25a36ad5-f975-4819-a2ff-df8526e07aa4', 'errorMessage': "Invalid value for date: 2019-10-20 - The date specified is not within the expected range. Earliest allowed date '2019-10-21'", 'errorCode': 'BAD_REQUEST'}}

# %%
status_data = res.json()['flightStatuses']
status_data[0].keys()
print(len(status_data))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-227800dc8824> in <module>()
# ----> 1 status_data = res.json()['flightStatuses']
#       2 status_data[0].keys()
#       3 print(len(status_data))
#
# KeyError: 'flightStatuses'

# %% [markdown]
# # Write to drive

# %%
'''
with open('/content/gdrive/My Drive/Colab Datasets/flightstats/test.json', 'w') as f:
  f.write(json.dumps(status_data))
  
'''
# Out:
# "\nwith open('/content/gdrive/My Drive/Colab Datasets/flightstats/test.json', 'w') as f:\n  f.write(json.dumps(status_data))\n  \n"

# %% [markdown]
# # Working with Date object

# %%
from datetime import datetime, date, timedelta
import time
print(time.time())
print(datetime.now())
# Out:
# 1572230926.113028
# 2019-10-28 02:48:46.114262

# %%
cur_time = datetime.now()

# %%
cur_time.hour
# Out:
# 2

# %% [markdown]
# # Collect Data on an interval

# %%
today = date.today()
print(today)
# Out:
# 2019-10-28

# %%
# math operation on days?
print(today.day - 5)
# Out:
# 23

# %%
# day of the week
print(date.weekday(today))
# Out:
# 0

# %%
# a date n days ago from today
diff = timedelta(days=7)
week_ago = today - diff
print(week_ago)
# Out:
# 2019-10-21

# %%
def print_days(days_ago):
    now = datetime.now()
  
    for i in range(days_ago):
        print(now - timedelta(days=i+1))
    
print_days(5)
# Out:
# 2019-10-27 02:48:46.207293
# 2019-10-26 02:48:46.207293
# 2019-10-25 02:48:46.207293
# 2019-10-24 02:48:46.207293
# 2019-10-23 02:48:46.207293

# %%
# let's make some changes to our original url builder function to make it more dynamic

def build_fs_url(airpt_code, date, start_hour, departure):
  
    print(date)
    
    # airport status endpoint
    url = 'https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status'
    airport = airpt_code
    dep = 'dep' if departure == True else 'arr'
    year = date.year
    month = date.month
    day = date.day
    hod = start_hour       

    url = f'{url}/{airport}/{dep}/{year}/{month}/{day}/{hod}'
    
    return url

add_params = {
    'appId' : 'c1272abb',
    'appKey': '58dfa6e47bc7ec284869e36f94613a6f',
    'utc': 'true',
    'numHours': '6'
}  


res = requests.get(build_fs_url('lax', datetime.now(), 13, True), params=add_params)

print(res.url)
print(res.status_code)
print(res.json())
# Out:
# 2019-10-28 02:48:46.233466
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/dep/2019/10/28/13?appId=c1272abb&appKey=58dfa6e47bc7ec284869e36f94613a6f&utc=true&numHours=6
# 200
# {'request': {'hourOfDay': {'requested': '13', 'interpreted': 13}, 'utc': {'requested': 'true', 'interpreted': True}, 'numHours': {'requested': '6', 'interpreted': 6}, 'url': 'https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/dep/2019/10/28/13?utc=true&numHours=6', 'nonstopOnly': {'interpreted': False}, 'airport': {'fsCode': 'LAX', 'requestedCode': 'lax'}, 'date': {'year': '2019', 'month': '10', 'day': '28', 'interpreted': '2019-10-28'}}, 'appendix': {'airlines': [{'fs': 'DL', 'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines', 'phoneNumber': '1-800-221-1212', 'active': True}, {'fs': 'UA', 'iata': 'UA', 'icao': 'UAL', 'name': 'United Airlines', 'phoneNumber': '1-800-864-8331', 'active': True}, {'fs': 'LY', 'iata': 'LY', 'icao': 'ELY', 'name': 'El Al', 'phoneNumber': '+ 972-3-9771111', 'active': True}, {'fs': 'QF', 'iata': 'QF', 'icao': 'QFA', 'name': 'Qantas', 'phoneNumber': '+61 2 9691 3636', 'active': True}, {'fs': 'IB', 'iata': 'IB', 'icao': 'IBE', 'name': 'Iberia', 'phoneNumber': '1800 772 4642', 'active': True}, {'fs': '4M', 'iata': '4M', 'icao': 'DSM', 'name': 'LATAM Airlines Argentina', 'active': True}, {'fs': 'MH', 'iata': 'MH', 'icao': 'MAS', 'name': 'Malaysia Airlines', 'phoneNumber': '+603 7843 3000', 'active': True}, {'fs': '4O', 'iata': '4O', 'icao': 'AIJ', 'name': 'Interjet', 'active': True}, {'fs': 'AA', 'iata': 'AA', 'icao': 'AAL', 'name': 'American Airlines', 'phoneNumber': '08457-567-567', 'active': True}, {'fs': 'QR', 'iata': 'QR', 'icao': 'QTR', 'name': 'Qatar Airways', 'phoneNumber': '+1 877 777 2827', 'active': True}, {'fs': 'AC', 'iata': 'AC', 'icao': 'ACA', 'name': 'Air Canada', 'phoneNumber': '1-888-422-7533', 'active': True}, {'fs': 'UX', 'iata': 'UX', 'icao': 'AEA', 'name': 'Air Europa', 'phoneNumber': '1.800.238.7672', 'active': True}, {'fs': 'AD', 'iata': 'AD', 'icao': 'AZU', 'name': 'Azul', 'active': True}, {'fs': 'EI', 'iata': 'EI', 'icao': 'EIN', 'name': 'Aer Lingus', 'phoneNumber': '1-800-IRISHAIR', 'active': True}, {'fs': 'AF', 'iata': 'AF', 'icao': 'AFR', 'name': 'Air France', 'phoneNumber': '1-800-237-2747', 'active': True}, {'fs': 'EK', 'iata': 'EK', 'icao': 'UAE', 'name': 'Emirates', 'phoneNumber': '800 777 3999', 'active': True}, {'fs': 'QX', 'iata': 'QX', 'icao': 'QXE', 'name': 'Horizon Air', 'active': True}, {'fs': 'MU', 'iata': 'MU', 'icao': 'CES', 'name': 'China Eastern Airlines', 'phoneNumber': '+86 21 95108', 'active': True}, {'fs': 'MW', 'iata': 'MW', 'icao': 'MHO', 'name': 'Mokulele Airlines', 'active': True}, {'fs': 'VA', 'iata': 'VA', 'icao': 'VOZ', 'name': 'Virgin Australia', 'active': True}, {'fs': 'AM', 'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico', 'phoneNumber': '1-800-237-6639', 'active': True}, {'fs': 'AR', 'iata': 'AR', 'icao': 'ARG', 'name': 'Aerolineas Argentinas', 'phoneNumber': '1-800-333-0276', 'active': True}, {'fs': 'AS', 'iata': 'AS', 'icao': 'ASA', 'name': 'Alaska Airlines', 'phoneNumber': '1-800-252-7522', 'active': True}, {'fs': 'F9', 'iata': 'F9', 'icao': 'FFT', 'name': 'Frontier Airlines', 'phoneNumber': '1-800-432-1359', 'active': True}, {'fs': 'B6', 'iata': 'B6', 'icao': 'JBU', 'name': 'JetBlue Airways', 'phoneNumber': '1-800-538-2583', 'active': True}, {'fs': 'EY', 'iata': 'EY', 'icao': 'ETD', 'name': 'Etihad Airways', 'active': True}, {'fs': 'AV', 'iata': 'AV', 'icao': 'AVA', 'name': 'SA AVIANCA', 'phoneNumber': '01-8000-1234 34', 'active': True}, {'fs': 'AY', 'iata': 'AY', 'icao': 'FIN', 'name': 'Finnair', 'phoneNumber': '+ 358 600 140 140', 'active': True}, {'fs': 'RJ', 'iata': 'RJ', 'icao': 'RJA', 'name': 'Royal Jordanian', 'active': True}, {'fs': '1I', 'iata': '1I', 'icao': 'EJA', 'name': 'NetJets Aviation', 'active': True}, {'fs': 'VN', 'iata': 'VN', 'icao': 'HVN', 'name': 'Vietnam Airlines', 'active': True}, {'fs': 'AZ', 'iata': 'AZ', 'icao': 'AZA', 'name': 'Alitalia', 'phoneNumber': '1-800-223-5730', 'active': True}, {'fs': 'NH', 'iata': 'NH', 'icao': 'ANA', 'name': 'ANA', 'phoneNumber': '1-800-235-9262', 'active ...

# %%
# On second thought, let's build a class called req_url

class req_url:
    
    # type_data is one of 'flight', 'airport', 'weather'
    def __init__(self, type_data, airpt_code='lax', date=date.today(), start_hour=24, departure=True):
      
        # credentials for both apis
        self.credentials = {
            'flightstats': {
                'appId' : 'c1272abb',
                'appKey': '58dfa6e47bc7ec284869e36f94613a6f'   
            },
            'darksky': {
                'key': '906506b4ec44e7ea8a9d51c2744d9959'
            }
        }
      
        # check to see if flight or airport info needed
        if type_data == 'flight':         
            self.source = 'https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status'
            self.dep = 'dep' if departure==True else 'arr'
            self.url = f'{self.source}/{airpt_code}/{self.dep}/{date.year}/{date.month}/{date.day}/{start_hour}'

            # additional parameters needed for request
            self.add_params = {
                'utc': 'true',
                'numHours': '6'
            }
            
        # dark sky api
        elif type_data == 'weather':
          
            # we get the lat and long of the airport requested using flightstats api
            res = requests.get(f'https://api.flightstats.com/flex/airports/rest/v1/json/iata/{airpt_code}', 
                               params=self.credentials['flightstats'])
            
            self.lat = res.json()['airports'][0]['latitude']
            self.long = res.json()['airports'][0]['longitude']
            self.time = res.json()['airports'][0]['localTime'][:-4]
            self.source = 'https://api.darksky.net/forecast'
            self.ds_key = '906506b4ec44e7ea8a9d51c2744d9959'      # dark sky api key
            self.url = f'{self.source}/{self.ds_key}/{self.lat},{self.long},{self.time}'
            
            # additional parameters for excluding components of the response such as minutely weather
            self.add_params = {
                'exclude': 'minutely'
            }
            
        else:
            print("Error: type_data must be one of 'flight' or 'weather'")

fs_test = req_url('flight', 'jfk')
ds_test = req_url('weather', 'jfk')
print(fs_test.url)
print(ds_test.url)
# Out:
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/jfk/dep/2019/10/28/24
# https://api.darksky.net/forecast/906506b4ec44e7ea8a9d51c2744d9959/40.642335,-73.78817,2019-10-28T05:31:53

# %%
# Collect data from everyday of past week
# first modify the print_days function to make api calls 
def collect_daily(days_ago):
    today = datetime.now()
  
    for i in range(days_ago):
        day = today - timedelta(days=i+1)
        print(build_fs_url('lax', day, 26, True))   # departures
        print(build_fs_url('lax', day, 26, False))  # arrivals

    
collect_daily(7)
# Out:
# 2019-10-27 02:48:46.491506
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/dep/2019/10/27/26
# 2019-10-27 02:48:46.491506
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/arr/2019/10/27/26
# 2019-10-26 02:48:46.491506
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/dep/2019/10/26/26
# 2019-10-26 02:48:46.491506
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/arr/2019/10/26/26
# 2019-10-25 02:48:46.491506
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/dep/2019/10/25/26
# 2019-10-25 02:48:46.491506
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/arr/2019/10/25/26
# 2019-10-24 02:48:46.491506
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/dep/2019/10/24/26
# 2019-10-24 02:48:46.491506
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/arr/2019/10/24/26
# 2019-10-23 02:48:46.491506
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/dep/2019/10/23/26
# 2019-10-23 02:48:46.491506
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/arr/2019/10/23/26
# 2019-10-22 02:48:46.491506
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/dep/2019/10/22/26
# 2019-10-22 02:48:46.491506
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/arr/2019/10/22/26
# 2019-10-21 02:48:46.491506
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/dep/2019/10/21/26
# 2019-10-21 02:48:46.491506
# https://api.flightstats.com/flex/flightstatus/rest/v2/json/airport/status/lax/arr/2019/10/21/26

# %%
# Since the api only allows a six-hour block at a time, we need to make 4 calls per day

time_of_day = 0

for i in range(4):
    time_of_day = i * 6
    print(time_of_day)
# Out:
# 0
# 6
# 12
# 18

# %%
# modify to accomodate hourOfDay
def collect_daily(days_ago):
    today = datetime.now()
  
    for i in range(days_ago):
        day = today - timedelta(days=i+1)
        time_of_day = 0
        
        for j in range(4):
            time_of_day = i * 6
            print(build_fs_url('lax', day))
    
    
#collect_daily(7)

def collect_data(airpt_code, days_ago):
  
    # for now, maximum value for days_ago allowed is 7
    if days_ago > 7:
        print('Error: Cannot get flight history more than 7 days ago.')
        return
  
    # first remove all previously downloaded data
    folder = '/content/gdrive/My Drive/Colab Datasets/flights_data'

    # remove all files in each of the folders present in the directory
    for each_fldr in os.listdir(folder):
        fldr_to_del = os.path.join(folder, each_fldr)
        
        for each_file in os.listdir(fldr_to_del):
            file = os.path.join(fldr_to_del, each_file)
            
            # delete folder and its contents
            try:
                if os.path.isfile(file):
                    os.unlink(file)
            except:
                print(e)
  
    now = datetime.now()
    
    # determine the starting hour of day for flight status  
    if now.hour < 6:
        start_hour = 6
    elif now.hour < 12:
        start_hour = 12
    elif now.hour < 18:
        start_hour = 18
    else:
        start_hour = 24
        
    for i in range(days_ago):        
        date = today - timedelta(days=i)
        
        # flight status in 6-hour windows
        if i > 0:
            start_hour = 24
        
        while start_hour > 0:
            
            start_hour = start_hour - 6
            #print(day, start_hour)
            #print(build_fs_url('lax', day, start_hour))
            
            # flightstats api response
            dep_req = req_url('flight', airpt_code, date, start_hour)
            arr_req = req_url('flight', airpt_code, date, start_hour, False)
            
            # merge the credentials and additional params dictionaries
            deps = requests.get(dep_req.url, params={**dep_req.credentials['flightstats'], **dep_req.add_params})
            arrs = requests.get(arr_req.url, params={**arr_req.credentials['flightstats'], **arr_req.add_params})
            
            # flight status info from response
            d_flt_sts = deps.json()['flightStatuses']    # departing flight statuses
            a_flt_sts = arrs.json()['flightStatuses']    # arriving flight statuses
                          
            # save json to google drive
            with open(f'/content/gdrive/My Drive/Colab Datasets/flights_data/departures/{date}.json', 'a') as f:
                f.write(json.dumps(d_flt_sts))
          
            with open(f'/content/gdrive/My Drive/Colab Datasets/flights_data/arrivals/{date}.json', 'a') as f:
                f.write(json.dumps(a_flt_sts))
                
            #print(res.url)
            
        # weather data in 1-day windows since api response already gives hourly weather cond
        weather_req = req_url('weather', airpt_code, date)
        
        # get weather data for airport and date
        weather = requests.get(weather_req.url, params={'exclude': ['minutely', 'daily', 'alerts']})
        #print(weather.url)
        
        # extract hourly data
        hourly_weather = weather.json()['hourly']['data']
            
        # store in google drive
        with open(f'/content/gdrive/My Drive/Colab Datasets/flights_data/weather/{date}.json', 'w') as f:
            f.write(json.dumps(hourly_weather))
                        
            
collect_data('pdx', 3)

# %%
print(datetime.today())
print(datetime.now())
print(f'{date.today()}-{datetime.now().hour}')
print(int(time.time()))
print(datetime.fromtimestamp(1571554800))
# Out:
# 2019-10-28 08:53:38.169901
# 2019-10-28 08:53:38.171746
# 2019-10-28-8
# 1572252818
# 2019-10-20 07:00:00

# %% [markdown]
# # Dark Sky API

# %%
# dark sky api request format
# https://api.darksky.net/forecast/[key]/[latitude],[longitude],[time]

# dark sky api request
def build_ds_url(airpt_code, time):
